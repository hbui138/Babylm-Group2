# %%
import os

# 1. GET THE MAPPED WORKSPACE DIRECTORY
# This grabs the current working directory of the Jupyter instance (e.g., /workspace or ./workspace)
ROOT_DIR = "/dss/dsshome1/0E/go54hem2/Babylm-Group2"

# Define the evaluation directory path
eval_dir = os.path.join(ROOT_DIR, "babylm-eval", "strict")

# Change directory so subsequent bash cells start here
os.chdir(eval_dir)

# Export paths as environment variables for bash cells
os.environ["BASELINE_PATH"] = os.path.join(ROOT_DIR, "model/babylm_pretrain_english_baseline")
os.environ["BILINGUAL_PATH"] = os.path.join(ROOT_DIR, "model/babylm_pretrain_bilingual")
os.environ["RANDOM_PATH"] = os.path.join(ROOT_DIR, "model/babylm_pretrain_bilingual_random")
os.environ["ENGLISH_POS_PATH"] = os.path.join(ROOT_DIR, "model/babylm_pretrain_english_with_pos")

# Print paths to verify correctness
print(f"Virtual Workspace Root: {ROOT_DIR}")
print(f"Current working directory changed to: {os.getcwd()}")
print(f"Baseline path: {os.environ['BASELINE_PATH']}")
print(f"Bilingual path: {os.environ['BILINGUAL_PATH']}")
print(f"Random path: {os.environ['RANDOM_PATH']}")
print(f"English POS path: {os.environ['ENGLISH_POS_PATH']}")

# %% [markdown]
# ## ENGLISH BASELINE

# %%
# %%bash
#
# # Initialize Conda using the absolute physical path
# source /dss/dsshome1/0E/go54hem2/miniconda/etc/profile.d/conda.sh
# conda activate babylm
#
# # Force Python to stream logs immediately
# export PYTHONUNBUFFERED=1
#
# echo "=========================================="
# echo ">>> [1/2] EVALUATING BASELINE MODEL: $BASELINE_PATH"
# echo "=========================================="
#
# echo "-> Run Zero-shot (BLiMP, COMPS, EWoK)..."
# # Using -x to print executing commands for sanity check
# bash scripts/eval_zero_shot.sh "$BASELINE_PATH" causal

# %%
# %%bash
#
# # Initialize Conda using the absolute physical path
# source /dss/dsshome1/0E/go54hem2/miniconda/etc/profile.d/conda.sh
# conda activate babylm
#
# # Force Python to stream logs immediately
# export PYTHONUNBUFFERED=1
#
# echo "-> Run Finetuning (GLUE)..."
# bash scripts/eval_finetuning.sh --model_path "$BASELINE_PATH"
#
# echo ">>> Baseline evaluation completed!"

# %% [markdown]
# ## BILINGUAL (POS SCAFFOLDING - EN-VI)

# %%
# %%bash
#
# # Initialize Conda for this new subshell
# source /dss/dsshome1/0E/go54hem2/miniconda/etc/profile.d/conda.sh
# conda activate babylm
#
# # Force Python to stream logs immediately
# export PYTHONUNBUFFERED=1
#
# echo "=========================================="
# echo ">>> [2/2] EVALUATING BILINGUAL MODEL: $BILINGUAL_PATH"
# echo "=========================================="
#
# echo "-> Run Zero-shot (BLiMP, COMPS, EWoK)..."
# bash scripts/eval_zero_shot.sh "$BILINGUAL_PATH" causal

# %%
# %%bash
#
# # Initialize Conda using the absolute physical path
# source /dss/dsshome1/0E/go54hem2/miniconda/etc/profile.d/conda.sh
# conda activate babylm
#
# # Force Python to stream logs immediately
# export PYTHONUNBUFFERED=1
#
# echo "-> Run Finetuning (GLUE)..."
# bash scripts/eval_finetuning.sh --model_path "$BILINGUAL_PATH"
#
# echo ">>> Bilingual evaluation completed!"

# %% [markdown]
# ## BILINGUAL RANDOM (EN-VI)

# %%
# %%bash
#
# # Initialize Conda using the absolute physical path
# source /dss/dsshome1/0E/go54hem2/miniconda/etc/profile.d/conda.sh
# conda activate babylm
#
# # Force Python to stream logs immediately
# export PYTHONUNBUFFERED=1
#
# echo "=========================================="
# echo ">>> EVALUATING RANDOM BILINGUAL MODEL: $RANDOM_PATH"
# echo "=========================================="
#
# echo "-> Run Zero-shot (BLiMP, COMPS, EWoK)..."
# # Using -x to print executing commands for sanity check
# bash scripts/eval_zero_shot.sh "$RANDOM_PATH" causal

# %%
# %%bash
#
# # Initialize Conda using the absolute physical path
# source /dss/dsshome1/0E/go54hem2/miniconda/etc/profile.d/conda.sh
# conda activate babylm
#
# # Force Python to stream logs immediately
# export PYTHONUNBUFFERED=1
#
# echo "-> Run Finetuning (GLUE)..."
# bash scripts/eval_finetuning.sh --model_path "$RANDOM_PATH"
#
# echo ">>> Bilingual evaluation completed!"

# %% [markdown]
# ## ENGLISH WITH POS

# %%
# %%bash
#
# # Initialize Conda using the absolute physical path
# source /dss/dsshome1/0E/go54hem2/miniconda/etc/profile.d/conda.sh
# conda activate babylm
#
# # Force Python to stream logs immediately
# export PYTHONUNBUFFERED=1
#
# echo "=========================================="
# echo ">>> EVALUATING ENGLISH + POS MODEL: $ENGLISH_POS_PATH"
# echo "=========================================="
#
# echo "-> Run Zero-shot (BLiMP, COMPS, EWoK)..."
# # Using -x to print executing commands for sanity check
# bash scripts/eval_zero_shot.sh "$ENGLISH_POS_PATH" causal

# %%
# %%bash
#
# # Initialize Conda using the absolute physical path
# source /dss/dsshome1/0E/go54hem2/miniconda/etc/profile.d/conda.sh
# conda activate babylm
#
# # Force Python to stream logs immediately
# export PYTHONUNBUFFERED=1
#
# echo "-> Run Finetuning (GLUE)..."
# bash scripts/eval_finetuning.sh --model_path "$ENGLISH_POS_PATH"
#
# echo ">>> Bilingual evaluation completed!"

# %% [markdown]
# ## COLLATE PREDICTIONS

# %%
# %%bash
#
# # Initialize Conda for this new subshell
# source /dss/dsshome1/0E/go54hem2/miniconda/etc/profile.d/conda.sh
# conda activate babylm
#
# echo "=========================================="
# echo ">>> Collating predictions for both models..."
# echo "=========================================="
#
# # Collate for Baseline
# echo "-> Collating Baseline..."
# bash scripts/collate_preds.sh "$BASELINE_PATH" causal strict-small
#
# # Collate for Bilingual
# echo "-> Collating Bilingual..."
# bash scripts/collate_preds.sh "$BILINGUAL_PATH" causal strict-small
#
# bash scripts/collate_preds.sh "$RANDOM_PATH" causal strict-small
#
# echo "=========================================="
# echo "Complete pipeline finished successfully!"
# echo "Check your respective model folders for the final JSON predictions."
# echo "=========================================="
